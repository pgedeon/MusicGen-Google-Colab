# %%
# !python3 -m pip install -U git+https://github.com/facebookresearch/audiocraft#egg=audiocraft
# !python3 -m pip install -U audiocraft
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/facebookresearch/audiocraft to /tmp/pip-install-jzw96q0n/audiocraft_9d6abd97508042aab0d3d26a184297bd
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/audiocraft /tmp/pip-install-jzw96q0n/audiocraft_9d6abd97508042aab0d3d26a184297bd
#   Resolved https://github.com/facebookresearch/audiocraft to commit 984b3755a1b37c85dcff24fb516b946ea75da4aa
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.0/31.0 MB 53.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 kB 8.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# Import requirments
from audiocraft.models import musicgen
from audiocraft.utils.notebook import display_audio
import torch
from audiocraft.data.audio import audio_write
import torchaudio

# %%
# Select model
model = musicgen.MusicGen.get_pretrained('medium', device='cuda')
# Set clip duration
model.set_generation_params(duration=10)

# %% [markdown]
# See our repo https://github.com/facebookresearch/audiocraft for more details on how to use this model!

# %%
import os

# Define the variable to store the filename count
filename_count += 1

# Set generative text for clips
descriptions = ['Dubstep bass line', 'Dubstep drop', 'Dubstep vocal']
wav = model.generate(descriptions)  # generates 3 samples.

# Show preview of clip
display_audio(wav, 32000)

# Save clips
for idx, one_wav in enumerate(wav):
    # Will save under {idx + filename_count}.wav, with loudness normalization at -14 db LUFS.
    audio_write(f'{descriptions[idx]}_{idx + filename_count}.wav', one_wav.cpu(), model.sample_rate, strategy="loudness")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Copy wav files to Google Drive

import shutil

# Define the source and destination folders
source_folder = '/content/'
destination_folder = '/content/drive/MyDrive/music/samples/dubstep/'

# Get all of the files in the source folder
files = os.listdir(source_folder)

# Filter the files to only include .mp4 files
mp4_files = [file for file in files if file.endswith('.wav')]

# Copy the .mp4 files to the destination folder
for file in mp4_files:
    shutil.copy(os.path.join(source_folder, file), os.path.join(destination_folder, file))
